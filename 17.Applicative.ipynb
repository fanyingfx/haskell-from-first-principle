-- %%
-- liftA :: Applicative f => (a->b) -> f a -> f b
-- liftA2 :: Applicative f =>  (a -> b -> c)  -> f a  -> f b  -> f c  
-- liftA3 :: Applicative f =>  (a -> b -> c -> d)  -> f a  -> f b  -> f c  -> f d
-- Out:
-- <interactive>:1:1: error: The type signature for ‘liftA’ lacks an accompanying binding
-- <interactive>:2:1: error: The type signature for ‘liftA2’ lacks an accompanying binding
-- <interactive>:3:1: error: The type signature for ‘liftA3’ lacks an accompanying binding

-- %%
import Control.Applicative
fmap (+1) [1,2,3]
pure (+1) <*> [1..3]
-- Out:
-- Line 3: Use <$>
-- Found:
-- pure (+ 1) <*> [1 .. 3]
-- Why not:
-- (+ 1) <$> [1 .. 3]
-- [2,3,4]
-- [2,3,4]

-- %%
-- [(*2),(*3)] <*> [4,5]
Just (*2) <*> Just 3
-- Out:
-- Just 6

-- %%
import Data.Monoid
("Woo", (+1)) <*> (" Hoo!", 2)
-- Out:
-- ("Woo Hoo!",3)

-- %%
import Control.Applicative 
f x = lookup x [(3, "hello"), (4, "julie"), (5, "kbai")]  
g y = lookup y [(7, "sup?"), (8, "chris"), (9, "aloha")]  
h z = lookup z [(2, 3), (5, 6), (7, 8)]  
m x = lookup x [(4, 10), (8, 13), (1, 9001)]

(++) <$> f 3 <*> g 7

(+) <$> h 5<*> m 6
-- Out:
-- Just "hellosup?"
-- Nothing

-- %%
:t liftA2
-- Out:
-- liftA2 :: forall (f :: * -> *) a b c. Applicative f => (a -> b -> c) -> f a -> f b -> f c

-- %%
(++) <$> getLine <*> getLine
-- Out:
-- "aacc"

-- %%
added :: Maybe Integer  
added = (+3) <$> (lookup 3 $ zip [1, 2, 3] [4, 5, 6])
y :: Maybe Integer  
y = lookup 3 $ zip [1, 2, 3] [4, 5, 6]
z :: Maybe Integer  
z = lookup 2 $ zip [1, 2, 3] [4, 5, 6]
tupled :: Maybe (Integer, Integer)  
tupled =  (,) <$> y <*> z
-- Out:
-- Line 2: Move brackets to avoid $
-- Found:
-- (+ 3) <$> (lookup 3 $ zip [1, 2, 3] [4, 5, 6])
-- Why not:
-- (+ 3) <$> lookup 3 (zip [1, 2, 3] [4, 5, 6])
-- Just (6,5)

-- %%
import Data.List (elemIndex)  
x :: Maybe Int  
x = elemIndex 3 [1, 2, 3, 4, 5]  
y :: Maybe Int  
y = elemIndex 4 [1, 2, 3, 4, 5]  
max' :: Int -> Int -> Int  
max' = max  
maxed :: Maybe Int  
maxed = max' <$> x  <*> y

-- %%
:t sum
-- Out:
-- sum :: forall (t :: * -> *) a. (Foldable t, Num a) => t a -> a

-- %%
xs = [1, 2, 3]  
ys = [4, 5, 6]  
x :: Maybe Integer  
x = lookup 3 $ zip xs ys  
y :: Maybe Integer  
y = lookup 2 $ zip xs ys  
summed :: Maybe Integer  
summed = fmap sum $ (,) <$> x <*> y
-- (Just sum) <$> x <*> y
summed
-- Out:
-- Just 5

-- %%
newtype Identity a = Identity a deriving(Eq,Ord,Show)
instance Functor Identity where
    fmap f (Identity a) = Identity (f a)
instance Applicative Identity where
    pure =  Identity
    (<*>) (Identity f) (Identity b) = Identity (f  b)
const <$> Identity [1,2,3] <*> Identity [9,9,9]
-- Out:
-- Identity [1,2,3]

-- %%
import Data.Monoid
newtype Constant a b = Constant {getConstant :: a} deriving (Eq,Ord,Show)
instance Functor (Constant a) where
    fmap _ (Constant a) = Constant a
instance Monoid a => Applicative (Constant a) where
    pure _ = Constant mempty
    (Constant a) <*> (Constant b) = Constant (a `mappend` b)

-- %%
validateLength :: Int -> String -> Maybe String  
validateLength maxLen s =  if (length s) > maxLen  then Nothing  else Just s  
newtype Name = Name String deriving (Eq, Show)  
newtype Address = Address String deriving (Eq, Show)  
mkName :: String -> Maybe Name  
mkName s = fmap Name $ validateLength 25 s  
mkAddress :: String -> Maybe Address  
mkAddress a = fmap Address $ validateLength 100 a
-- Out:
-- Line 2: Redundant bracket
-- Found:
-- (length s) > maxLen
-- Why not:
-- length s > maxLenLine 6: Use <$>
-- Found:
-- fmap Name $ validateLength 25 s
-- Why not:
-- Name <$> validateLength 25 sLine 8: Use <$>
-- Found:
-- fmap Address $ validateLength 100 a
-- Why not:
-- Address <$> validateLength 100 a

-- %%
data Person =  Person Name Address  deriving (Eq, Show)  
mkPerson :: String -> String -> Maybe Person  
mkPerson n a =  
    case mkName n of  
        Nothing -> Nothing 
        Just n' ->  
            case mkAddress a of  
                Nothing -> Nothing  
                Just a' ->  Just $ Person n' a'

-- %%
:t fmap Person (mkName "Babe")
maybeAddy = mkAddress "old macdonald's"
:t maybeAddy
Person <$> mkName "Babe" <*> maybeAddy
-- Out:
-- fmap Person (mkName "Babe") :: Maybe (Address -> Person)
-- maybeAddy :: Maybe Address
-- Just (Person (Name "Babe") (Address "old macdonald's"))

-- %%
data Cow = Cow { name :: String ,age :: Int ,weight :: Int } deriving (Eq,Show)

noEmpty :: String -> Maybe String
noEmpty "" = Nothing
noEmpty str = Just str

noNegative :: Int -> Maybe Int
noNegative n| n>=0 = Just n
            | otherwise = Nothing
-- cowFromString :: String -> Int->Int ->Maybe Cow
-- cowFromString name' age' weight' = 
--     case noEmpty name' of
--         Nothing -> Nothing
--         Just nammy -> 
--             case noNegative age' of
--                 Nothing -> Nothing
--                 Just agey ->
--                     case noNegative weight' of
--                         Nothing -> Nothing
--                         Just weighty -> Just (Cow nammy agey weighty)

cowFromString :: String->Int->Int->Maybe Cow
cowFromString name' age' weight' = Cow <$> noEmpty name' <*> noNegative age' <*> noNegative weight'

-- %%
:t (<*>)
:t (<*>) :: Maybe (a->b) -> Maybe a -> Maybe b

:t (<$>)
:t fmap :: (a->b)->Maybe a->Maybe b
-- Out:
-- (<*>) :: forall (f :: * -> *) a b. Applicative f => f (a -> b) -> f a -> f b
-- (<*>) :: Maybe (a->b) -> Maybe a -> Maybe b :: forall a b. Maybe (a -> b) -> Maybe a -> Maybe b
-- (<$>) :: forall (f :: * -> *) a b. Functor f => (a -> b) -> f a -> f b
-- fmap :: (a->b)->Maybe a->Maybe b :: forall a b. (a -> b) -> Maybe a -> Maybe b

-- %%
import Control.Applicative
:t liftA2
-- Out:
-- liftA2 :: forall (f :: * -> *) a b c. Applicative f => (a -> b -> c) -> f a -> f b -> f c

-- %%
const <$> Just "Hello" <*> Just "World"
(,,,) <$> Just 90 <*> Just 10 <*> Just "Tierness" <*> Just [1, 2, 3]
-- Out:
-- Just "Hello"
-- Just (90,10,"Tierness",[1,2,3])

-- %%
pure id <*> [1..5]
pure id <*> (+1) $ 2
-- Out:
-- Line 1: Use <$>
-- Found:
-- pure id <*> [1 .. 5]
-- Why not:
-- id <$> [1 .. 5]Line 2: Use <$>
-- Found:
-- pure id <*> (+ 1)
-- Why not:
-- (id <$> (+ 1))
-- [1,2,3,4,5]
-- 3

-- %%
-- pure (+1 ) <*> pure 1 :: Maybe Int
:info Num
-- :t pure 1
-- Out:
-- type Num :: * -> Constraint
-- class Num a where
--   (+) :: a -> a -> a
--   (-) :: a -> a -> a
--   (*) :: a -> a -> a
--   negate :: a -> a
--   abs :: a -> a
--   signum :: a -> a
--   fromInteger :: Integer -> a
--   {-# MINIMAL (+), (*), abs, signum, fromInteger, (negate | (-)) #-}
--   	-- Defined in ‘GHC.Num’
-- instance Num IHaskellTH.Exp -- Defined in ‘Data.Reflection’
-- instance Num a => Num (IHaskellTH.Q a) -- Defined in ‘Data.Reflection’
-- instance Num IHaskellTH.Type -- Defined in ‘Data.Reflection’
-- instance Num Double -- Defined in ‘GHC.Float’
-- instance Num Float -- Defined in ‘GHC.Float’
-- instance Num Int -- Defined in ‘GHC.Num’
-- instance Num Integer -- Defined in ‘GHC.Num’
-- instance Num Word -- Defined in ‘GHC.Num’
-- instance forall k (f :: k -> *) (a :: k). Num (f a) => Num (Alt f a) -- Defined in ‘base:Data.Semigroup.Internal’
-- instance Num a => Num (Product a) -- Defined in ‘base:Data.Semigroup.Internal’
-- instance Num a => Num (Sum a) -- Defined in ‘base:Data.Semigroup.Internal’
-- instance (Applicative f, Num a) => Num (Ap f a) -- Defined in ‘Data.Monoid’
-- instance Num PixCount -- Defined in ‘ihaskell-widgets-0.3.1.0-LJ3vfoEkMUl3ELNPsmbYWZ:IHaskell.Display.Widgets.Common’
-- instance forall a k (b :: k). Num a => Num (Const a b) -- Defined in ‘Data.Functor.Const’

-- %%
-- pure ($ 1)  <*> [(+1),(+2)]
-- Just (+3) <*> pure 1
pure ($ 1) <*> Just (+3)
-- Out:
-- Line 3: Use <$>
-- Found:
-- pure ($ 1) <*> Just (+ 3)
-- Why not:
-- ($ 1) <$> Just (+ 3)
-- Just 4

-- %%
import Data.Monoid  
import Test.QuickCheck  
import Test.QuickCheck.Checkers  
import Test.QuickCheck.Classes
-- Out:
-- <interactive>:1:1: error:
--     Could not find module ‘Test.QuickCheck.Checkers’
--     Perhaps you meant
--       Test.QuickCheck.Features (from QuickCheck-2.14.2)
--       Test.QuickCheck.Modifiers (from QuickCheck-2.14.2)
--     Use -v (or `:set -v` in ghci) to see a list of the files searched for.

-- %%
1 <> (2 :: Sum Integer)
-- Out:
-- Sum {getSum = 3}
